# %% [markdown]
# ## Inspecting the dataset:

# %%
import pandas as pd

data = pd.read_csv('all_signals.csv')
#data.iloc[1000:1200,:]
data
# Out:
#        actual   predict1  predict2  predict3  predict4  predict5   predict6
# 0         0.0  20.792572  2.264052  2.264052  2.264052  2.264052   9.764052
# 1         0.0  19.428677  0.900157  0.900157  0.900157  0.900157   8.400157
# 2         0.0  20.007258  2.940019  2.940019  1.478738  1.478738   8.978738
# 3         0.0  21.269413  4.202174  4.202174  2.740893  2.740893  10.240893
# 4         0.0  20.896078  3.828839  3.828839  2.367558  2.367558   9.867558
# ...       ...        ...       ...       ...       ...       ...        ...
# 30482     0.0  18.439183       NaN       NaN       NaN       NaN        NaN
# 30483     0.0  20.028197       NaN       NaN       NaN       NaN        NaN
# 30484     0.0  17.293372       NaN       NaN       NaN       NaN        NaN
# 30485     0.0  19.587188       NaN       NaN       NaN       NaN        NaN
# 30486     0.0  18.069021       NaN       NaN       NaN       NaN        NaN
#
# [30487 rows x 7 columns]

# %%
# data1 = pd.read_csv('resampled.csv')
# resampled = data1['0']
# print(len(resampled))
# print(type(resampled))
# data['actual_resample'] = resampled
# data.head()

# %%
from scipy import signal

secs = len(data['actual'])/30
samps = secs*10
samps = int(samps)
re_sample = signal.resample(data['actual'], samps)
re_sample = pd.Series(re_sample)
print(len(re_sample))
print(type(re_sample))
# Out:
# 10162
# <class 'pandas.core.series.Series'>

# %%
data['actual_resample'] = re_sample
data
# Out:
#        actual   predict1  predict2  predict3  predict4  predict5   predict6  \
# 0         0.0  20.792572  2.264052  2.264052  2.264052  2.264052   9.764052
# 1         0.0  19.428677  0.900157  0.900157  0.900157  0.900157   8.400157
# 2         0.0  20.007258  2.940019  2.940019  1.478738  1.478738   8.978738
# 3         0.0  21.269413  4.202174  4.202174  2.740893  2.740893  10.240893
# 4         0.0  20.896078  3.828839  3.828839  2.367558  2.367558   9.867558
# ...       ...        ...       ...       ...       ...       ...        ...
# 30482     0.0  18.439183       NaN       NaN       NaN       NaN        NaN
# 30483     0.0  20.028197       NaN       NaN       NaN       NaN        NaN
# 30484     0.0  17.293372       NaN       NaN       NaN       NaN        NaN
# 30485     0.0  19.587188       NaN       NaN       NaN       NaN        NaN
# 30486     0.0  18.069021       NaN       NaN       NaN       NaN        NaN
#
#        actual_resample
# 0             0.000355
# ...

# %%
data = data.fillna(0)
data.isna().any()
# Out:
# actual             False
# predict1           False
# predict2           False
# predict3           False
# predict4           False
# predict5           False
# predict6           False
# actual_resample    False
# dtype: bool

# %%
data = data[data.actual_resample > 0]
data.reset_index(inplace=True, drop=True)
data.head()
# Out:
#    actual   predict1  predict2  predict3  predict4  predict5  predict6  \
# 0     0.0  20.792572  2.264052  2.264052  2.264052  2.264052  9.764052
# 1     0.0  20.007258  2.940019  2.940019  1.478738  1.478738  8.978738
# 2     0.0  20.896078  3.828839  3.828839  2.367558  2.367558  9.867558
# 3     0.0  19.978608  2.911369  2.911369  1.450088  1.450088  8.950088
# 4     0.0  18.925301  1.858062  1.858062  0.396781  0.396781  7.896781
#
#    actual_resample
# 0         0.000355
# 1         0.000356
# 2         0.000358
# 3         0.000360
# 4         0.000362

# %%
len(data)
# Out:
# 9568

# %% [markdown]
# ### Visualizing before frequency conversion

# %%
import seaborn as sns
import matplotlib.pyplot as plt

actual_speed = data[["actual_resample", "predict1"]]
plt.figure(figsize=(20,10))
sns.lineplot(data=actual_speed)
#plt.axis([0,500,0,25])
plt.show()

# %% [markdown]
# ### Converting the actual speed from 30hz to 10hz:

# %%
#data['actual'] = data.actual.apply(lambda x: (10 * x)/30)
#data.iloc[1000:1200,:]

# %% [markdown]
# ### Visualizing after frequency conversion:

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# actual_speed = data[["actual", "predict1"]]
# plt.figure(figsize=(20,10))
# sns.lineplot(data=actual_speed)
# plt.show()

# %% [markdown]
# ## Building the Synchronization function:

# %%
from fastdtw import *
from scipy.spatial.distance import *

def synchronizise(column1, column2):
    data[column1] = data[column1].fillna(data[column1].mean())
    data[column2] = data[column2].fillna(data[column2].mean())
    x = data[column1]
    y = data[column2]
    
    # using the dynamic time warping model:
    distance, path = fastdtw(x, y, dist=euclidean)
    result = []
    for i in range(0,len(path)):
        result.append([data[column1].iloc[path[i][0]], data[column2].iloc[path[i][1]]])
        
    data_sync = pd.DataFrame(data=result,columns=[column1, column2])
    return data_sync

# %%
data_sync_1 = synchronizise('actual_resample', 'predict1')
data_sync_2 = synchronizise('actual_resample', 'predict2')
data_sync_3 = synchronizise('actual_resample', 'predict3')
data_sync_4 = synchronizise('actual_resample', 'predict4')
data_sync_5 = synchronizise('actual_resample', 'predict5')
data_sync_6 = synchronizise('actual_resample', 'predict6')

# %%
len(data_sync_1)
# Out:
# 16296

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def visualize(df, predict):
    actual_speed = df[[predict, "actual_resample"]]
    #palette = sns.color_palette("mako_r", 6)
    plt.figure(figsize=(20,10))
    sns.lineplot(data=actual_speed)
    plt.show()

# %%
visualize(data_sync_1, 'predict1')

# %%
from sklearn.metrics import r2_score
list1 = ['predict1', 'predict2', 'predict3', 'predict4', 'predict5', 'predict6']
score_list = []
for i in list1: 
    score = r2_score(data['actual_resample'], data[i])
    score_list.append(score)
    
list2 = [data_sync_1, data_sync_2, data_sync_3, data_sync_4, data_sync_5, data_sync_6]
score_list2 = []
for i in range(len(list1)):
    score = r2_score(list2[i]['actual_resample'], list2[i][list1[i]])
    score_list2.append(score)

# %%
score_df = pd.DataFrame([score_list, score_list2], columns=list1, index=["Before_Sync", "After_Sync"])
score_df
# Out:
#              predict1  predict2  predict3  predict4  predict5  predict6
# Before_Sync -0.735230 -0.889982 -0.889982 -1.587699 -1.587699 -1.148006
# After_Sync   0.778599  0.729681  0.729681  0.838378  0.838378  0.857698

# %%
visualize(data_sync_2, 'predict2')
